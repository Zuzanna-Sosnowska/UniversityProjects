# %% [markdown]
# # Lista 3
#
# ### Zadanie 1

# %%
import string
import matplotlib.pyplot as plt
from numpy import number


def letter_histogram(text, alphabet=list(string.ascii_lowercase)):
    letter_dict = {letter : 0 for letter in alphabet}
    for letter in alphabet:
        number_of_occurences = text.count(letter.lower())
        letter_dict[letter] = number_of_occurences
    x = list(letter_dict.keys())
    y = list(letter_dict.values())
    plt.bar(x, y)
    plt.title("Częstość wystąpień liter")
    plt.show()
    
text = open("text.txt", "r").read()
letter_histogram(text)

# %% [markdown]
# ### Zadanie 2

# %%
text_pl = open("text_pl.txt", "r", encoding='utf-8').read()
letter_histogram(text=text_pl, alphabet=list("aąbcćdeęfghijklłmnńoópqrsśtuwxyzźż"))

# %% [markdown]
# ### Zadanie 3
